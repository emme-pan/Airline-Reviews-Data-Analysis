# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
ac_df = pd.read_csv("AC_reviews.csv")
ac_df
# Out:
#       Unnamed: 0 Aircraft Type of Traveller       Seat Type     Date Flown  \
# 0              0      NaN    Family Leisure   Economy Class   October 2023
# 1              1     A321    Family Leisure   Economy Class  February 2024
# 2              2     A319          Business  Business Class  December 2023
# 3              3      NaN      Solo Leisure   Economy Class   January 2024
# 4              4      NaN      Solo Leisure   Economy Class   January 2024
# ...          ...      ...               ...             ...            ...
# 2333        2333      NaN               NaN   Economy Class            NaN
# 2334        2334      NaN               NaN   Economy Class            NaN
# 2335        2335      NaN               NaN   Economy Class            NaN
# 2336        2336      NaN               NaN   Economy Class            NaN
# 2337        2337      NaN               NaN   Economy Class            NaN
#
#       Seat Comfort  Cabin Staff Service  Food & Beverages  \
# ...
